# %%
import warnings
warnings.filterwarnings("ignore")
import os
import dotenv

import json
import pandas as pd
import requests

dotenv.load_dotenv()

import redis
from langchain.vectorstores.redis import Redis
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
redis_host = os.getenv("REDIS_HOST")
redis_password = os.getenv("REDIS_PASS")


r = redis.Redis(
  host=redis_host,
  port=14266,
  password=redis_password,
 )

# %% [markdown]
# ## Preparing Data

# %%
def get_data():
	url = "https://eeg-backend-hfehdmd4hxfagsgu.canadacentral-01.azurewebsites.net/api/users/product"

	response = requests.get(url)

	return response.json()

# %%
data = get_data()
print(data)
# Out:
# [{'chemicalProperties': {}, 'seller': {'name': 'ChemWorld Ltd.', 'contactInfo': '', 'phone': '', 'address': '', 'user': 1}, 'productType': 'Industrial Supply', 'productId': 'CHM-56789-BBB', 'productName': 'Sodium Hydroxide (Caustic Soda)', 'productIdentification': '99% Pure NaOH', 'purityComposition': '99% NaOH, 1% Moisture', 'quantity': 1200, 'unit': 'kg', 'price': '20.00', 'currency': 'USD', 'rating': '4.70', 'category': 'Industrial Supplies', 'subCategory': 'Chemicals', 'minimumOrderQuantity': 10, 'availabilityStatus': 'In Stock', 'location': 'Detroit, USA', 'deliveryTime': '2-4 business days', 'images': ['https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fi5.walmartimages.com%2Fasr%2Ff7151025-f254-4c23-ac71-3b5ee8a4486f_1.06599ced82e3e88315e88b4048430fac.jpeg&f=1&nofb=1&ipt=be0e8019ee80faaaa7dac31cdeeb924453906bf2e2711a5e0a1afdcb7679d521&ipo=images'], 'manufactureDate': '2024-02-01', 'expiryDate': '2025-02-01', 'shippingCost': '25.00'}, {'physicalProperties': {'length': '12 meters', 'diameter': '16 mm', 'weight': '15 kg per rod'}, 'chemicalProperties': {'carbonContent': '0.25%'}, 'seller': {'name': 'SteelMakers Inc.', 'contactInfo': '', 'phone': '', 'address': '', 'user': 2}, 'productType': 'Construction Material', 'productId': 'TMT-22334-CCC', 'productName': 'TMT Iron Rod', 'productIdentification': 'Grade Fe 500D', 'purityComposition': '99% Iron, 1% Alloy', 'quantity': 2000, 'unit': 'rods', 'price': '50.00', 'currency': 'USD', 'rating': '4.20', 'category': 'Construction Materials', 'subCategory': 'Iron Rods', 'minimumOrderQuantity': 50, 'availabilityStatus': 'In Stock', 'location': 'Pittsburgh, USA', 'deliveryTime': '5-7 business days', 'images': ['https://waritigiafrica.com/wp-content/uploads/2019/12/rebar-768x512.jpg'], 'manufactureDate': '2023-11-05', 'shippingCost': '100.00', 'discount': 1}, {'physicalProperties': {'weight': '15 kg'}, 'chemicalProperties': {}, 'seller': {'name': 'WeldPro Equipment', 'contactInfo': '', 'phone': '', 'address': '', 'user': 3}, 'productType': 'Industrial Supply', 'productId': 'WLD-77889-DDD', 'productName': 'MIG Welding Machine', 'productIdentification': 'Model MIG-350', 'quantity': 100, 'unit': 'pieces', 'price': '500.00', 'currency': 'USD', 'rating': '4.50', 'category': 'Industrial Supplies', 'subCategory': 'Welding Equipment', 'minimumOrderQuantity': 1, 'availabilityStatus': 'In Stock', 'location': 'Houston, USA', 'deliveryTime': '3-5 business days', 'images': ['https://m.media-amazon.com/images/I/71uvCWPWMfL._AC_SL1500_.jpg'], 'manufactureDate': '2024-01-01', 'shippingCost': '50.00', 'discount': 3}, {'physicalProperties': {'length': '6 meters', 'diameter': '50 mm', 'weight': '2 kg per pipe'}, 'chemicalProperties': {}, 'seller': {'name': 'PipeMasters LLC', 'contactInfo': '', 'phone': '', 'address': '', 'user': 4}, 'productType': 'Construction Material', 'productId': 'PVC-33445-EEE', 'productName': 'PVC Water Supply Pipe', 'productIdentification': 'NSF Certified, Class 315', 'purityComposition': '100% Virgin PVC', 'quantity': 3000, 'unit': 'pipes', 'price': '12.00', 'currency': 'USD', 'rating': '4.30', 'category': 'Construction Materials', 'subCategory': 'PVC Pipes', 'minimumOrderQuantity': 20, 'availabilityStatus': 'In Stock', 'location': 'Miami, USA', 'deliveryTime': '5-7 business days', 'images': ['https://kennedys.net.au/wp-content/uploads/2018/10/PVC-Ag-Pipe-Kennedys-Garden-Supplies-155.jpg'], 'manufactureDate': '2024-05-01', 'shippingCost': '20.00', 'discount': 4}, {'physicalProperties': {'weight': '25 kg'}, 'chemicalProperties': {}, 'seller': {'name': 'PaintPro Co.', 'contactInfo': '', 'phone': '', 'address': '', 'user': 5}, 'productType': 'Industrial Supply', 'productId': 'PAINT-88900-FFF', 'productName': 'Industrial Epoxy Paint', 'productIdentification': 'Corrosion-Resistant, ISO 12944 Compliant', 'purityComposition': '95% Epoxy Resin, 5% Solvent', 'quantity': 500, 'unit': 'buckets', 'price': '300.00', 'currency': 'USD', 'rating': '4.70', 'category': 'Industrial Suppli ...

# %%
#create a dataframe with the keys as columns and values as rows
df = pd.DataFrame(data)
df.head()
# Out:
#            chemicalProperties  \
# 0                          {}
# 1  {'carbonContent': '0.25%'}
# 2                          {}
# 3                          {}
# 4                          {}
#
#                                               seller            productType  \
# 0  {'name': 'ChemWorld Ltd.', 'contactInfo': '', ...      Industrial Supply
# 1  {'name': 'SteelMakers Inc.', 'contactInfo': ''...  Construction Material
# 2  {'name': 'WeldPro Equipment', 'contactInfo': '...      Industrial Supply
# 3  {'name': 'PipeMasters LLC', 'contactInfo': '',...  Construction Material
# 4  {'name': 'PaintPro Co.', 'contactInfo': '', 'p...      Industrial Supply
#
#          productId                      productName  \
# 0    CHM-56789-BBB  Sodium Hydroxide (Caustic Soda)
# 1    TMT-22334-CCC                     TMT Iron Rod
# 2    WLD-77889-DDD              MIG Welding Machine
# 3    PVC-33445-EEE            PVC Water Supply Pipe
# 4  PAINT-88900-FFF           Industrial Epoxy Paint
#
#                       productIdentification            purityComposition  \
# 0                             99% Pure NaOH        99% NaOH, 1% Moisture
# 1                             Grade Fe 500D           99% Iron, 1% Alloy
# 2                             Model MIG-350                          NaN
# 3                  NSF Certified, Class 315              100% Virgin PVC
# 4  Corrosion-Resistant, ISO 12944 Compliant  95% Epoxy Resin, 5% Solvent
#
#    quantity     unit   price  ... minimumOrderQuantity availabilityStatus  \
# 0      1200       kg   20.00  ...                   10           In Stock
# 1      2000     rods   50.00  ...                   50           In Stock
# 2       100   pieces  500.00  ...                    1           In Stock
# 3      3000    pipes   12.00  ...                   20           In Stock
# 4       500  buckets  300.00  ...                    1           In Stock
#
#           location       deliveryTime  \
# 0     Detroit, USA  2-4 business days
# 1  Pittsburgh, USA  5-7 business days
# 2     Houston, USA  3-5 business days
# 3       Miami, USA  5-7 business days
# 4     Detroit, USA  3-5 business days
#
#                                               images manufactureDate  \
# 0  [https://external-content.duckduckgo.com/iu/?u...      2024-02-01
# 1  [https://waritigiafrica.com/wp-content/uploads...      2023-11-05
# 2  [https://m.media-amazon.com/images/I/71uvCWPWM...      2024-01-01
# 3  [https://kennedys.net.au/wp-content/uploads/20...      2024-05-01
# 4  [https://5.imimg.com/data5/SELLER/Default/2023...      2024-07-01
#
#    expiryDate shippingCost                                 physicalProperties  \
# 0  2025-02-01        25.00                                                NaN
# 1         NaN       100.00  {'length': '12 meters', 'diameter': '16 mm', '...
# 2         NaN        50.00                                {'weight': '15 kg'}
# 3         NaN        20.00  {'length': '6 meters', 'diameter': '50 mm', 'w...
# 4  2025-07-01        35.00                                {'weight': '25 kg'}
#
#   discount
# 0      NaN
# 1      1.0
# 2      3.0
# 3      4.0
# 4      5.0
#
# [5 rows x 24 columns]

# %%
df.fillna("Unknown", inplace=True)
df.head()
# Out:
#            chemicalProperties  \
# 0                          {}
# 1  {'carbonContent': '0.25%'}
# 2                          {}
# 3                          {}
# 4                          {}
#
#                                               seller            productType  \
# 0  {'name': 'ChemWorld Ltd.', 'contactInfo': '', ...      Industrial Supply
# 1  {'name': 'SteelMakers Inc.', 'contactInfo': ''...  Construction Material
# 2  {'name': 'WeldPro Equipment', 'contactInfo': '...      Industrial Supply
# 3  {'name': 'PipeMasters LLC', 'contactInfo': '',...  Construction Material
# 4  {'name': 'PaintPro Co.', 'contactInfo': '', 'p...      Industrial Supply
#
#          productId                      productName  \
# 0    CHM-56789-BBB  Sodium Hydroxide (Caustic Soda)
# 1    TMT-22334-CCC                     TMT Iron Rod
# 2    WLD-77889-DDD              MIG Welding Machine
# 3    PVC-33445-EEE            PVC Water Supply Pipe
# 4  PAINT-88900-FFF           Industrial Epoxy Paint
#
#                       productIdentification            purityComposition  \
# 0                             99% Pure NaOH        99% NaOH, 1% Moisture
# 1                             Grade Fe 500D           99% Iron, 1% Alloy
# 2                             Model MIG-350                      Unknown
# 3                  NSF Certified, Class 315              100% Virgin PVC
# 4  Corrosion-Resistant, ISO 12944 Compliant  95% Epoxy Resin, 5% Solvent
#
#    quantity     unit   price  ... minimumOrderQuantity availabilityStatus  \
# 0      1200       kg   20.00  ...                   10           In Stock
# 1      2000     rods   50.00  ...                   50           In Stock
# 2       100   pieces  500.00  ...                    1           In Stock
# 3      3000    pipes   12.00  ...                   20           In Stock
# 4       500  buckets  300.00  ...                    1           In Stock
#
#           location       deliveryTime  \
# 0     Detroit, USA  2-4 business days
# 1  Pittsburgh, USA  5-7 business days
# 2     Houston, USA  3-5 business days
# 3       Miami, USA  5-7 business days
# 4     Detroit, USA  3-5 business days
#
#                                               images manufactureDate  \
# 0  [https://external-content.duckduckgo.com/iu/?u...      2024-02-01
# 1  [https://waritigiafrica.com/wp-content/uploads...      2023-11-05
# 2  [https://m.media-amazon.com/images/I/71uvCWPWM...      2024-01-01
# 3  [https://kennedys.net.au/wp-content/uploads/20...      2024-05-01
# 4  [https://5.imimg.com/data5/SELLER/Default/2023...      2024-07-01
#
#    expiryDate shippingCost                                 physicalProperties  \
# 0  2025-02-01        25.00                                            Unknown
# 1     Unknown       100.00  {'length': '12 meters', 'diameter': '16 mm', '...
# 2     Unknown        50.00                                {'weight': '15 kg'}
# 3     Unknown        20.00  {'length': '6 meters', 'diameter': '50 mm', 'w...
# 4  2025-07-01        35.00                                {'weight': '25 kg'}
#
#   discount
# 0  Unknown
# 1      1.0
# 2      3.0
# 3      4.0
# 4      5.0
#
# [5 rows x 24 columns]

# %%
df["chemicalProperties"] = df["chemicalProperties"].apply(lambda x: "Unknown" if len(x) == 0 else x)
df.head()
# Out:
#            chemicalProperties  \
# 0                     Unknown
# 1  {'carbonContent': '0.25%'}
# 2                     Unknown
# 3                     Unknown
# 4                     Unknown
#
#                                               seller            productType  \
# 0  {'name': 'ChemWorld Ltd.', 'contactInfo': '', ...      Industrial Supply
# 1  {'name': 'SteelMakers Inc.', 'contactInfo': ''...  Construction Material
# 2  {'name': 'WeldPro Equipment', 'contactInfo': '...      Industrial Supply
# 3  {'name': 'PipeMasters LLC', 'contactInfo': '',...  Construction Material
# 4  {'name': 'PaintPro Co.', 'contactInfo': '', 'p...      Industrial Supply
#
#          productId                      productName  \
# 0    CHM-56789-BBB  Sodium Hydroxide (Caustic Soda)
# 1    TMT-22334-CCC                     TMT Iron Rod
# 2    WLD-77889-DDD              MIG Welding Machine
# 3    PVC-33445-EEE            PVC Water Supply Pipe
# 4  PAINT-88900-FFF           Industrial Epoxy Paint
#
#                       productIdentification            purityComposition  \
# 0                             99% Pure NaOH        99% NaOH, 1% Moisture
# 1                             Grade Fe 500D           99% Iron, 1% Alloy
# 2                             Model MIG-350                      Unknown
# 3                  NSF Certified, Class 315              100% Virgin PVC
# 4  Corrosion-Resistant, ISO 12944 Compliant  95% Epoxy Resin, 5% Solvent
#
#    quantity     unit   price  ... minimumOrderQuantity availabilityStatus  \
# 0      1200       kg   20.00  ...                   10           In Stock
# 1      2000     rods   50.00  ...                   50           In Stock
# 2       100   pieces  500.00  ...                    1           In Stock
# 3      3000    pipes   12.00  ...                   20           In Stock
# 4       500  buckets  300.00  ...                    1           In Stock
#
#           location       deliveryTime  \
# 0     Detroit, USA  2-4 business days
# 1  Pittsburgh, USA  5-7 business days
# 2     Houston, USA  3-5 business days
# 3       Miami, USA  5-7 business days
# 4     Detroit, USA  3-5 business days
#
#                                               images manufactureDate  \
# 0  [https://external-content.duckduckgo.com/iu/?u...      2024-02-01
# 1  [https://waritigiafrica.com/wp-content/uploads...      2023-11-05
# 2  [https://m.media-amazon.com/images/I/71uvCWPWM...      2024-01-01
# 3  [https://kennedys.net.au/wp-content/uploads/20...      2024-05-01
# 4  [https://5.imimg.com/data5/SELLER/Default/2023...      2024-07-01
#
#    expiryDate shippingCost                                 physicalProperties  \
# 0  2025-02-01        25.00                                            Unknown
# 1     Unknown       100.00  {'length': '12 meters', 'diameter': '16 mm', '...
# 2     Unknown        50.00                                {'weight': '15 kg'}
# 3     Unknown        20.00  {'length': '6 meters', 'diameter': '50 mm', 'w...
# 4  2025-07-01        35.00                                {'weight': '25 kg'}
#
#   discount
# 0  Unknown
# 1      1.0
# 2      3.0
# 3      4.0
# 4      5.0
#
# [5 rows x 24 columns]

# %%
columns = df.columns
corpus = []
for i in range(df.shape[0]):
        text = ""
        for col in columns:
                text += col+ ": " + str(df[col][i]) + " "
        corpus.append(text)
corpus[:2]
# Out:
# ["chemicalProperties: Unknown seller: {'name': 'ChemWorld Ltd.', 'contactInfo': '', 'phone': '', 'address': '', 'user': 1} productType: Industrial Supply productId: CHM-56789-BBB productName: Sodium Hydroxide (Caustic Soda) productIdentification: 99% Pure NaOH purityComposition: 99% NaOH, 1% Moisture quantity: 1200 unit: kg price: 20.00 currency: USD rating: 4.70 category: Industrial Supplies subCategory: Chemicals minimumOrderQuantity: 10 availabilityStatus: In Stock location: Detroit, USA deliveryTime: 2-4 business days images: ['https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fi5.walmartimages.com%2Fasr%2Ff7151025-f254-4c23-ac71-3b5ee8a4486f_1.06599ced82e3e88315e88b4048430fac.jpeg&f=1&nofb=1&ipt=be0e8019ee80faaaa7dac31cdeeb924453906bf2e2711a5e0a1afdcb7679d521&ipo=images'] manufactureDate: 2024-02-01 expiryDate: 2025-02-01 shippingCost: 25.00 physicalProperties: Unknown discount: Unknown ",
#  "chemicalProperties: {'carbonContent': '0.25%'} seller: {'name': 'SteelMakers Inc.', 'contactInfo': '', 'phone': '', 'address': '', 'user': 2} productType: Construction Material productId: TMT-22334-CCC productName: TMT Iron Rod productIdentification: Grade Fe 500D purityComposition: 99% Iron, 1% Alloy quantity: 2000 unit: rods price: 50.00 currency: USD rating: 4.20 category: Construction Materials subCategory: Iron Rods minimumOrderQuantity: 50 availabilityStatus: In Stock location: Pittsburgh, USA deliveryTime: 5-7 business days images: ['https://waritigiafrica.com/wp-content/uploads/2019/12/rebar-768x512.jpg'] manufactureDate: 2023-11-05 expiryDate: Unknown shippingCost: 100.00 physicalProperties: {'length': '12 meters', 'diameter': '16 mm', 'weight': '15 kg per rod'} discount: 1.0 "]

# %% [markdown]
# ## Product Summaries

# %%
def create_prod_summary(data):
	llm = ChatOpenAI(
		model="gpt-3.5-turbo",
		temperature=0,
		max_tokens=None,
		timeout=None,
		max_retries=2,
		api_key=OPENAI_API_KEY,
	)

	message = f"Here is a product data {data}. Your job is to create a listing of the entire product. Mention all the features and details present in the data."

	response = llm.invoke(message)
	return response.content

# %%
summary = []
for prod in corpus:
	summary.append(create_prod_summary(prod))

summary[:2]
# Out:
# ['Product Listing:\n- Product ID: CHM-56789-BBB\n- Product Name: Sodium Hydroxide (Caustic Soda)\n- Seller: ChemWorld Ltd.\n- Contact Information: Not provided\n- Phone: Not provided\n- Address: Not provided\n- User: 1\n- Product Type: Industrial Supply\n- Purity: 99% Pure NaOH\n- Composition: 99% NaOH, 1% Moisture\n- Quantity: 1200 kg\n- Price: $20.00 USD\n- Rating: 4.70\n- Category: Industrial Supplies\n- Subcategory: Chemicals\n- Minimum Order Quantity: 10\n- Availability Status: In Stock\n- Location: Detroit, USA\n- Delivery Time: 2-4 business days\n- Images: [https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fi5.walmartimages.com%2Fasr%2Ff7151025-f254-4c23-ac71-3b5ee8a4486f_1.06599ced82e3e88315e88b4048430fac.jpeg&f=1&nofb=1&ipt=be0e8019ee80faaaa7dac31cdeeb924453906bf2e2711a5e0a1afdcb7679d521&ipo=images]\n- Manufacture Date: 2024-02-01\n- Expiry Date: 2025-02-01\n- Shipping Cost: $25.00\n- Physical Properties: Unknown\n- Discount: Unknown',
#  'Product Listing:\n- Product ID: TMT-22334-CCC\n- Product Name: TMT Iron Rod\n- Product Type: Construction Material\n- Product Identification: Grade Fe 500D\n- Quantity: 2000 rods\n- Price: $50.00 per rod\n- Seller: SteelMakers Inc.\n- Seller Contact Info: Not provided\n- Seller Rating: 4.20\n- Carbon Content: 0.25%\n- Purity Composition: 99% Iron, 1% Alloy\n- Minimum Order Quantity: 50 rods\n- Availability Status: In Stock\n- Location: Pittsburgh, USA\n- Delivery Time: 5-7 business days\n- Manufacture Date: November 5, 2023\n- Expiry Date: Unknown\n- Shipping Cost: $100.00\n- Physical Properties: \n  - Length: 12 meters\n  - Diameter: 16 mm\n  - Weight: 15 kg per rod\n- Discount: 1.0\n- Category: Construction Materials\n- Subcategory: Iron Rods\n- Images: [https://waritigiafrica.com/wp-content/uploads/2019/12/rebar-768x512.jpg]']

# %% [markdown]
# ## Vector Embeddings

# %%
embed_model = OpenAIEmbeddings(api_key=OPENAI_API_KEY)

# %% [markdown]
# ### Redis DB

# %%
redis_url = f"redis://:{redis_password}@{redis_host}:14266"
index_name = "product_index"

# %%
schema = {
    "summary": "TEXT",  # Field for product summaries (TEXT type)
    "id": "NUMERIC",  # Metadata (NUMERIC type for IDs)
    "embedding": {  # Field for embeddings (VECTOR type)
        "TYPE": "FLOAT32",  # Data type of vector
        "DIM": 768,  # Dimension of the vectors (adjust according to your model)
        "DISTANCE_METRIC": "COSINE"  # Similarity metric for search
    }
}

# %%
# metadata = [{"id": i} for i in range(len(summary))]
# redis_vectorstore = Redis.from_texts(
#   texts=summary,
#   metadatas=metadata,
#   embedding=embed_model,
#   index_name=index_name,
#   redis_url=redis_url,
# )

# %%
redis_instance = Redis.from_existing_index(
  embedding=embed_model,
  index_name=index_name,
  redis_url=redis_url,
  schema=schema,
)

# %%
# Redis.drop_index(index_name, redis_url=redis_url, delete_documents=True)

# %% [markdown]
# ## LLM Query

# %%
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_openai import ChatOpenAI
from langchain_redis import RedisChatMessageHistory

# %%
question_template = """You are an expert in summarizing questions. 
					Your goal is to reduce a question to its simplest form while retaining the semantic meaning. 
             		Try to be as deterministic as possible
					Below is the question:
					{question}
					Output will be a semantically similar question that will be used to query an existing database."""

prompt = """You are an expert in answering questions on product related queries.
					You have to provide the most relevant answer to the question based on the product data.
					If multiple products are relevant, you can provide a list of those products. 
					Here is the product data:
					{data}
					And here is the question:
					{question}
					For queries like Hi or Hello you can respond with greetings or a polite message."""



def llm_response(question):
	llm = ChatOpenAI(
		model="gpt-3.5-turbo",
		temperature=0,
		max_tokens=None,
		timeout=None,
		max_retries=2,
		api_key=OPENAI_API_KEY,
	)
	
	question = question_template.format(question=question)
	modified_question = llm.invoke(question).content
	tokenized_query = modified_question.split(" ")
	redis_result = redis_instance.similarity_search(query=modified_question, k=5)
	final_result = ""
	for res in redis_result:
		final_result += res.page_content + "\n"
	answer_msg = prompt.format(data=final_result, question=modified_question)
	response = llm.invoke(answer_msg)
	return response.content

# %%
x = llm_response("List the iron items available")
print(x)
# Out:
# The iron items that are currently in stock are:
# 1. Iron Ore - Bulk by OreMining Corp.
# 2. TMT Iron Rod by SteelMakers Inc.

# %%
prompt = ChatPromptTemplate.from_messages([
        ("system", """You are an expert in answering questions about products. 
                     Answer based on the retrieved product data below:
                     {context}
                     
                     For greetings like "Hi" or "Hello", respond politely.
                     If multiple products are relevant, list all of them.
                     If you're not sure about something, say so."""),
        MessagesPlaceholder(variable_name="history"),
        ("human", "{question}")
    ])

# %%
# First define the retrieval function
def retrieve_docs(question):
    modified_question = llm.invoke(question_template.format(question=question)).content
    redis_result = redis_instance.similarity_search(query=modified_question, k=5)
    return "\n".join(res.page_content for res in redis_result)

llm = ChatOpenAI(
		model="gpt-3.5-turbo",
		temperature=0,
		max_tokens=None,
		timeout=None,
		max_retries=2,
		api_key=OPENAI_API_KEY,
	)

chain = prompt | llm

# Create Redis history manager
def get_redis_history(session_id: str) -> BaseChatMessageHistory:
    return RedisChatMessageHistory(
        session_id=session_id,
		redis_client=r,
    )

# Create chain with history
chain_with_history = RunnableWithMessageHistory(
    chain,
    get_redis_history,
    input_messages_key="question",
    history_messages_key="history"
)

# Example usage:
def chat_with_memory(question: str, session_id: str):
    # Get context from Redis vector store
    context = retrieve_docs(question)
    
    # Run chain with memory
    response = chain_with_history.invoke(
        {"question": question, "context": context},
        config={"configurable": {"session_id": session_id}}
    )
    return response.content

# Test the chat
session_id = "test_session_1"
print(chat_with_memory("Hi my name is Ronit", session_id))
# Out:
# Hello Ronit! How can I assist you today?

# %%
print(chat_with_memory("What is my name?", session_id))
# Out:
# Your name is Ronit. How can I assist you further, Ronit?

# %%
import requests

url = "http://localhost:8000/api/chat"
data = {
    "question": "What is the price of the iron items?",
    "session_id": "test_session_1"
}

response = requests.post(url, json=data)

if response.status_code == 200:
    result = response.json()
    answer = result["answer"]
    print("Bot:", answer)
else:
    print("Error:", response.status_code, response.text)
# Out:
# Bot: The prices of the iron items available are as follows:
#
# 1. **Iron Ore - Bulk**
#    - Price: $150.00 per ton
#
# 2. **TMT Iron Rod**
#    - Price: $50.00 per rod
#
# If you have any more questions or need further details, feel free to ask.
